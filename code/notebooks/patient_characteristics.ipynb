# %%
import pandas as pd
import numpy as np
def create_dataframe(clinical_characteristics_df, weak_labels_df, full_labels_df):
    
    def _calc_num_slices_columns(row, pool='sum'):
        assert pool in ['sum', 'max']
        num_slices = np.array([float(s) for s in str(row['n_slices']).split('|') if s.isnumeric()])
        if len(num_slices) == 0:
            return float('nan')
        if pool == 'max':
            return num_slices.max()
        elif pool =='sum':
            return num_slices.sum()
        
        
    weak_labels_df = weak_labels_df[["SubjectID", "Gelabeled", "n_slices"]]
    full_labels_df = full_labels_df[['SubjectID', "Gesegmenteerd?", "Data split"]]
    df = pd.merge(weak_labels_df, full_labels_df, on=["SubjectID"], how='outer')
    df = pd.merge(df, clinical_characteristics_df, on=["SubjectID"], how='outer')
    
    df['sum_slices'] = df.apply (lambda row: _calc_num_slices_columns(row, pool='sum'), axis=1)
    df['max_slices'] = df.apply (lambda row: _calc_num_slices_columns(row, pool='max'), axis=1)
    
    #df = pd.concat([clinical_characteristics_df, weak_labels_df, full_labels_df], axis=0, join='inner')
    return df

def visualize_characteristics(df, rel_cols=None, num_cols=None):
    def _visualize_subset(sub_df):
        if rel_cols != None:
            for c in rel_cols:
                assert c in sub_df.columns, f"Column {c} not in dataframe"
        print("----"*20)
        total = len([s for s in sub_df.SubjectID.unique() if not s.isspace()]) # don't count empty subjectID '' 
        print(f"Total: {total}")
        for col in sub_df.columns:
            if rel_cols != None:
                if col not in rel_cols:
                    continue
                    
            unique_vals = sub_df[col].unique()
            # approximation, assume all categorical values have less than 5 values
            categorical = len(unique_vals) < 5
            if categorical == True:
                print(f"Column: {col}")
                for v in unique_vals:
                    count = (sub_df[col] == v).sum()
                    print(f"\t {v}: {count} / ({count/total*100:.2f}%)")
            else:
                if num_cols != None:
                    if col in num_cols:
                        vals = np.array([float(str(x).replace(",", ".")) for x in sub_df[col] if not str(x).isspace()])
                        print(f"Column {col}, mean {np.nanmean(vals):.2f}/ std ({np.nanstd(vals):.2f})")
        return
    
    show_columns = []
    weakly_labeled = df[df['Gelabeled'] == 'Ja']
    weakly_labeled_train = weakly_labeled[~weakly_labeled['Data split'].isin(['validation', 'test'])]
    fully_labeled = df[df['Gesegmenteerd?'] == 'Ja']
    fully_labeled = fully_labeled[~fully_labeled['SubjectID'].isin(['DRAUMC0669', 'DRAUMC0851', 'DRAUMC1231', 'DRAUMC1236'])] # not checked by fleur
    fully_labeled = fully_labeled[~fully_labeled['SubjectID'].isin(['DRAUMC0587'])] # manual segmentation on cropped PSIR image, cropped MAG not available
    fully_labeled_train = fully_labeled[fully_labeled['Data split'].isin(['train'])]
    fully_labeled_val = fully_labeled[fully_labeled['Data split'].isin(['validation'])]
    fully_labeled_test = fully_labeled[fully_labeled['Data split'].isin(['test'])]
    #1. visualize all data
    print("----"*20)
    print("FULL DATASET")
    _visualize_subset(df)
    #2. visualize slice-level weakly-labeled data
    print("----"*20)
    print("SLICE-LABELED TRAIN DATASET")
    _visualize_subset(weakly_labeled_train)
    #3. visualize stack-level weakly labeled data
    
    #4. visualize fully labeled data // Train
    print("----"*20)
    print("FULLY-LABELED TRAIN DATASET")
    _visualize_subset(fully_labeled_train)
    #5. visualize fully labeled data // Val
    print("----"*20)
    print("FULLY-LABELED VALIDATION DATASET")
    _visualize_subset(fully_labeled_val)
    #6. Visualize fully labeled data // Test
    print("----"*20)
    print("FULLY-LABELED TEST DATASET")
    _visualize_subset(fully_labeled_test)
    
    
    return

# %%
char_df = pd.read_csv(r"\\amc.intra\users\R\rcklein\home\deeprisk\sheets\DeepRiskICD_Database_n=1261_2sept2021_export8nov2021.csv", sep=None)
weak_labels_df = pd.read_excel(r"\\amc.intra\users\R\rcklein\home\deeprisk\weakly_supervised\data\weak_labels_n=657.xlsx")
full_labels_df = pd.read_excel(r"\\amc.intra\users\R\rcklein\home\deeprisk\sheets\full_labels_15june2022.xlsx")
# Out:
# C:\Users\rcklein\AppData\Local\Temp\ipykernel_10672\4221041672.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   char_df = pd.read_csv(r"\\amc.intra\users\R\rcklein\home\deeprisk\sheets\DeepRiskICD_Database_n=1261_2sept2021_export8nov2021.csv", sep=None)

# %%
#print(weak_labels_df.columns)
#print(full_labels_df.columns)
#print(char_df.columns)
df = create_dataframe(char_df, weak_labels_df, full_labels_df)
print(len(df))
print(len(df['SubjectID'].unique()))
print(df.columns)
# Out:
# 1293
# 1262
# Index(['SubjectID', 'Gelabeled', 'n_slices', 'Gesegmenteerd?', 'Data split',
#        'Geslacht', 'Age', 'Ischemische_ziekte',
#        'Soort_ischemische_ziekte#Stabiel_coronairlijden',
#        'Soort_ischemische_ziekte#Myocard_infarct',
#        ...
#        'CMRontslag', 'folllow_up_MK_calc', 'day_to_ICDtherapy_1y_MK',
#        'day_to_ICDtherapy_2y_MK', 'day_to_ICDtherapy_3y_MK',
#        'day_to_ICDtherapy_4y_MK', 'day_to_ICDtherapy_5y_MK',
#        'day_to_ICDtherapy_10y_MK', 'sum_slices', 'max_slices'],
#       dtype='object', length=704)

# %%
# check for double ocurring SubjectIDs
for sid in df['SubjectID'].unique():
    if len(df[df['SubjectID'] == sid]) > 1:
        print("Multiple with subject id :", sid, "!")
        #print(df[df['SubjectID'] == sid])
# Out:
# Multiple with subject id :   !

# %%
# check if all segmented patients have weak labels
full = df[(df['Gesegmenteerd?'] == 'Ja')]
full[full['Gelabeled'] != 'Ja']
# Out:
# Empty DataFrame
# Columns: [SubjectID, Gelabeled, n_slices, Gesegmenteerd?, Data split, Geslacht, Age, Ischemische_ziekte, Soort_ischemische_ziekte#Stabiel_coronairlijden, Soort_ischemische_ziekte#Myocard_infarct, Soort_ischemische_ziekte#PCI, Soort_ischemische_ziekte#CABG, cardiomyopathie, Overig_CMP, Afib, Aflutter, Geleidingsstoornis, Ventriculaire_tachycardie#Nee, Ventriculaire_tachycardie#nsVT, Ventriculaire_tachycardie#sustained_VT, Ventriculaire_tachycardie#VF, OHCA, Ablatie, Pacemaker, NYHA_klasse, ICD_LVEF, ICD_LVEF_AANGEPAST_29_4, ICD_LVEF_6_categorien, ICD_LVEF_5_categorien, ICD_Datum_LVEF, ICD_LVEF_methode, ICD_LVEF_bepaald, Opmerkingen_VG, Vitamine_K, Plaatjes_aggregatie, NOAC, Betablokker, ARB, Aldosteronremmer, Diuretica, Anti_aritmica, Antiaritmica_soort#Amiodarone, Antiaritmica_soort#Digoxine, Antiaritmica_soort#Sotalol, Antiaritmica_soort#Overig, Opmerkingen_med, ICD_Date_ECG, Hartfrequentie, Ritme_ecg, Overig_ritme_ecg, QRS, Geleidingsstoornis_ecg, Hartas, Opmerking_ECG, Diabetes, COPD, CVA, Roken, Hypertensie, Hypercholesterolaemie, Familie_HVZ, Perifeer_vaatlijden, Hospitalisatie_preimplant, ICD_Lengte, ICD_Gewicht, ICD_BMI, Date_lab, Lab_hb, Lab_natrium, Lab_kalium, Lab_kreatinine, Lab_eGFR, Lab_NTproBNP, ICD_Date_MRI, Date_ICD_implantatie, Indicatie_ICD_implantatie, Procedure, Soort_ICD_device, Opmerkingen_ICD_device, ICD_MRI_verricht, ICD_Locatie_MRI, ICD_Date_CMR, ICD_EDV_MRI, ICD_ESV_MRI, ICD_LVEF_MRI, ICD_Contrast_gegeven, ICD_LGE_aanwezig, ICD_LGE_aankleuringspatroon, Overig_aankleuringspatroon, Datum_follow_up, Date_ICDtherapy, Eindpunt#Geen_ICD_therapie_niet_overleden, Eindpunt#Terechte_ICD_therapie_DEEPRISK1, Days2TerechteTherapie, Soort_ICDtherapie, Ritme_terechte_ICD_therapie, HF_ritmestoornis, ICD_Therapy_Cumulatief, Date_overlijden, Days2Death, ...]
# Index: []
#
# [0 rows x 704 columns]

# %%
RELEVANT_COLUMNS = ['Gelabeled', 'n_slices', 'Gesegmenteerd?',
                   'Data split', 'Geslacht', 'Age',
                   'Ischemische_ziekte', 'Soort_ischemische_ziekte#Stabiel_coronairlijden', 'Soort_ischemische_ziekte#Myocard_infarct',
                   'Soort_ischemische_ziekte#PCI', 'Soort_ischemische_ziekte#CABG',
                   'ICD_LGE_aanwezig', 'sum_slices', 'max_slices']
NUMERICAL_COLUMNS = ['Age', 'sum_slices', 'max_slices']
visualize_characteristics(df, rel_cols=RELEVANT_COLUMNS, num_cols=NUMERICAL_COLUMNS)
# Out:
# --------------------------------------------------------------------------------
# FULL DATASET
# --------------------------------------------------------------------------------
# Total: 1261
# Column: Gelabeled
# 	 Ja: 483 / (38.30%)
# 	 Uitgevallen: 117 / (9.28%)
# 	 Onduidelijk: 57 / (4.52%)
# 	 nan: 0 / (0.00%)
# Column: Gesegmenteerd?
# 	 Ja: 125 / (9.91%)
# 	 nan: 0 / (0.00%)
# 	 Uitgevallen: 47 / (3.73%)
# 	 Nog niet: 44 / (3.49%)
# Column: Data split
# 	 train: 88 / (6.98%)
# 	 nan: 0 / (0.00%)
# 	 validation: 12 / (0.95%)
# 	 test: 25 / (1.98%)
# Column: Geslacht
# 	 0: 964 / (76.45%)
# 	 1: 297 / (23.55%)
# 	  : 32 / (2.54%)
# Column Age, mean 64.74/ std (12.04)
# Column: Ischemische_ziekte
# 	 1: 797 / (63.20%)
# 	 0: 464 / (36.80%)
# 	  : 32 / (2.54%)
# Column: Soort_ischemische_ziekte#Stabiel_coronairlijden
# 	 0: 1216 / (96.43%)
# 	 1: 45 / (3.57%)
# 	  : 32 / (2.54%)
# Column: Soort_ischemische_ziekte#Myocard_infarct
# 	 1: 628 / (49.80%)
# 	 0: 633 / (50.20%)
# 	  : 32 / (2.54%)
# Column: Soort_ischemische_ziekte#PCI
# 	 0: 786 / (62.33%)
# 	 1: 475 / (37.67%)
# 	  : 32 / (2.54%)
# Column: Soort_ischemische_ziekte#CABG
# 	 0: 1037 / (82.24%)
# 	 1: 224 / (17.76%)
# 	  : 32 / (2.54%)
# Column sum_slices, mean 12.07/ std (2.95)
# Column max_slices, mean 11.37/ std (1.81)
# --------------------------------------------------------------------------------
# SLICE-LABELED TRAIN DATASET
# --------------------------------------------------------------------------------
# Total: 446
# Column: Gelabeled
# 	 Ja: 446 / (100.00%)
# Column: Gesegmenteerd?
# 	 Ja: 89 / (19.96%)
# 	 nan: 0 / (0.00%)
# 	 Uitgevallen: 13 / (2.91%)
# 	 Nog niet: 34 / (7.62%)
# Column: Data split
# 	 train: 88 / (19.73%)
# 	 nan: 0 / (0.00%)
# Column: Geslacht
# 	 0: 347 / (77.80%)
# 	 1: 99 / (22.20%)
# Column Age, mean 62.51/ std (12.81)
# Column: Ischemische_ziekte
# 	 1: 289 / (64.80%)
# 	 0: 157 / (35.20%)
# Column: Soort_ischemische_ziekte#Stabiel_coronairlijden
# 	 0: 430 / (96.41%)
# 	 1: 16 / (3.59%)
# Column: Soort_ischemische_ziekte#Myocard_infarct
# 	 1: 228 / (51.12%)
# 	 0: 218 / (48.88%)
# Column: Soort_ischemische_ziekte#PCI
# 	 0: 260 / (58.30%)
# 	 1: 186 / (41.70%)
# Column: Soort_ischemische_ziekte#CABG
# 	 0: 382 / (85.65%)
# 	 1: 64 / (14.35%)
# Column: ICD_LGE_aanwezig
# 	 1: 343 / (76.91%)
# 	 0: 103 / (23.09%)
# Column sum_slices, mean 11.98/ std (2.66)
# Column max_slices, mean 11.34/ std (1.79)
# --------------------------------------------------------------------------------
# FULLY-LABELED TRAIN DATASET
# --------------------------------------------------------------------------------
# Total: 81
# Column: Gelabeled
# 	 Ja: 81 / (100.00%)
# Column: Gesegmenteerd?
# 	 Ja: 81 / (100.00%)
# Column: Data split
# 	 train: 81 / (100.00%)
# Column: Geslacht
# 	 0: 65 / (80.25%)
# 	 1: 16 / (19.75%)
# Column Age, mean 60.77/ std (14.88)
# Column: Ischemische_ziekte
# 	 1: 42 / (51.85%)
# 	 0: 39 / (48.15%)
# Column: Soort_ischemische_ziekte#Stabiel_coronairlijden
# 	 0: 79 / (97.53%)
# 	 1: 2 / (2.47%)
# Column: Soort_ischemische_ziekte#Myocard_infarct
# 	 1: 32 / (39.51%)
# 	 0: 49 / (60.49%)
# Column: Soort_ischemische_ziekte#PCI
# 	 0: 55 / (67.90%)
# 	 1: 26 / (32.10%)
# Column: Soort_ischemische_ziekte#CABG
# 	 0: 69 / (85.19%)
# 	 1: 12 / (14.81%)
# Column: ICD_LGE_aanwezig
# 	 1: 56 / (69.14%)
# 	 0: 25 / (30.86%)
# Column sum_slices, mean 12.22/ std (2.62)
# Column max_slices, mean 11.57/ std (1.51)
# --------------------------------------------------------------------------------
# FULLY-LABELED VALIDATION DATASET
# --------------------------------------------------------------------------------
# Total: 12
# Column: Gelabeled
# 	 Ja: 12 / (100.00%)
# Column: Gesegmenteerd?
# 	 Ja: 12 / (100.00%)
# Column: Data split
# 	 validation: 12 / (100.00%)
# Column: Geslacht
# 	 0: 11 / (91.67%)
# 	 1: 1 / (8.33%)
# Column Age, mean 52.80/ std (12.11)
# Column: Ischemische_ziekte
# 	 0: 6 / (50.00%)
# 	 1: 6 / (50.00%)
# Column: Soort_ischemische_ziekte#Stabiel_coronairlijden
# 	 0: 11 / (91.67%)
# 	 1: 1 / (8.33%)
# Column: Soort_ischemische_ziekte#Myocard_infarct
# 	 0: 7 / (58.33%)
# 	 1: 5 / (41.67%)
# Column: Soort_ischemische_ziekte#PCI
# 	 0: 9 / (75.00%)
# 	 1: 3 / (25.00%)
# Column: Soort_ischemische_ziekte#CABG
# 	 0: 10 / (83.33%)
# 	 1: 2 / (16.67%)
# Column: ICD_LGE_aanwezig
# 	 1: 10 / (83.33%)
# 	 0: 2 / (16.67%)
# Column sum_slices, mean 11.42/ std (1.80)
# Column max_slices, mean 10.92/ std (1.19)
# --------------------------------------------------------------------------------
# FULLY-LABELED TEST DATASET
# --------------------------------------------------------------------------------
# Total: 24
# Column: Gelabeled
# 	 Ja: 24 / (100.00%)
# Column: Gesegmenteerd?
# 	 Ja: 24 / (100.00%)
# Column: Data split
# 	 test: 24 / (100.00%)
# Column: Geslacht
# 	 0: 19 / (79.17%)
# 	 1: 5 / (20.83%)
# Column Age, mean 62.93/ std (15.10)
# Column: Ischemische_ziekte
# 	 0: 4 / (16.67%)
# 	 1: 20 / (83.33%)
# Column: Soort_ischemische_ziekte#Stabiel_coronairlijden
# 	 0: 23 / (95.83%)
# 	 1: 1 / (4.17%)
# Column: Soort_ischemische_ziekte#Myocard_infarct
# 	 0: 7 / (29.17%)
# 	 1: 17 / (70.83%)
# Column: Soort_ischemische_ziekte#PCI
# 	 0: 10 / (41.67%)
# 	 1: 14 / (58.33%)
# Column: Soort_ischemische_ziekte#CABG
# 	 0: 21 / (87.50%)
# 	 1: 3 / (12.50%)
# Column: ICD_LGE_aanwezig
# 	 1: 20 / (83.33%)
# 	 0: 4 / (16.67%)
# Column sum_slices, mean 12.50/ std (3.04)
# Column max_slices, mean 11.50/ std (1.55)

# %%
for x in df.columns:
    print(x)
# Out:
# SubjectID
# Gelabeled
# n_slices
# Gesegmenteerd?
# Data split
# Geslacht
# Age
# Ischemische_ziekte
# Soort_ischemische_ziekte#Stabiel_coronairlijden
# Soort_ischemische_ziekte#Myocard_infarct
# Soort_ischemische_ziekte#PCI
# Soort_ischemische_ziekte#CABG
# cardiomyopathie
# Overig_CMP
# Afib
# Aflutter
# Geleidingsstoornis
# Ventriculaire_tachycardie#Nee
# Ventriculaire_tachycardie#nsVT
# Ventriculaire_tachycardie#sustained_VT
# Ventriculaire_tachycardie#VF
# OHCA
# Ablatie
# Pacemaker
# NYHA_klasse
# ICD_LVEF
# ICD_LVEF_AANGEPAST_29_4
# ICD_LVEF_6_categorien
# ICD_LVEF_5_categorien
# ICD_Datum_LVEF
# ICD_LVEF_methode
# ICD_LVEF_bepaald
# Opmerkingen_VG
# Vitamine_K
# Plaatjes_aggregatie
# NOAC
# Betablokker
# ARB
# Aldosteronremmer
# Diuretica
# Anti_aritmica
# Antiaritmica_soort#Amiodarone
# Antiaritmica_soort#Digoxine
# Antiaritmica_soort#Sotalol
# Antiaritmica_soort#Overig
# Opmerkingen_med
# ICD_Date_ECG
# Hartfrequentie
# Ritme_ecg
# Overig_ritme_ecg
# QRS
# Geleidingsstoornis_ecg
# Hartas
# Opmerking_ECG
# Diabetes
# COPD
# CVA
# Roken
# Hypertensie
# Hypercholesterolaemie
# Familie_HVZ
# Perifeer_vaatlijden
# Hospitalisatie_preimplant
# ICD_Lengte
# ICD_Gewicht
# ICD_BMI
# Date_lab
# Lab_hb
# Lab_natrium
# Lab_kalium
# Lab_kreatinine
# Lab_eGFR
# Lab_NTproBNP
# ICD_Date_MRI
# Date_ICD_implantatie
# Indicatie_ICD_implantatie
# Procedure
# Soort_ICD_device
# Opmerkingen_ICD_device
# ICD_MRI_verricht
# ICD_Locatie_MRI
# ICD_Date_CMR
# ICD_EDV_MRI
# ICD_ESV_MRI
# ICD_LVEF_MRI
# ICD_Contrast_gegeven
# ICD_LGE_aanwezig
# ICD_LGE_aankleuringspatroon
# Overig_aankleuringspatroon
# Datum_follow_up
# Date_ICDtherapy
# Eindpunt#Geen_ICD_therapie_niet_overleden
# Eindpunt#Terechte_ICD_therapie_DEEPRISK1
# Days2TerechteTherapie
# Soort_ICDtherapie
# Ritme_terechte_ICD_therapie
# HF_ritmestoornis
# ICD_Therapy_Cumulatief
# Date_overlijden
# Days2Death
# Eindpunt#Overleden
# Oorzaak_overlijden
# Date_defibrillator_off
# Opmerkingen_FU
# Date_MRI
# Date_ECG
# Date_implantatie
# DaysECG2Implant
# Opmerking
# RecordID_CMR
# Date_CMR
# InstituteAbbreviation
# RecordCreationDate
# sex
# centrum
# DOS
# kliniek
# anzi
# overigZHS
# kliniek_EMC
# overigZHS_EMC
# kliniek_RUMC
# overigZHS_RUMC
# kliniek_Maasstad
# overigZHS_Maasstad
# kliniek_Tergooi
# overigZHS_Tergooi
# status
# VG
# vraag
# indicatie
# project
# ICo
# epro
# verslager
# functie
# medebeoordeler
# functie_ass
# supervisor
# supervisor_EMC
# supervisor_RUMC
# supervisor_RUMC_2
# supervisor_Maasstad
# supervisor_Maasstad_2
# supervisor_Tergooi
# supervisor_Tergooi_2
# scanner
# scanner_EMC
# scanner_RUMC
# scanner_Maasstad
# scanner_Tergooi
# technieken#bSSFP_cine
# technieken#bSSFP_real_time_cine
# technieken#bSSFP_cine_tagging
# technieken#multislice_bSSFP
# technieken#T1_TSE
# technieken#T2_TSE
# technieken#T2_mapping
# technieken#T2_mappin1
# technieken#2D_flow_mapping
# technieken#4D_flow_mapping
# technieken#3D_bSSFPdual_excitation
# technieken#3D_noncontrast_MRA
# technieken#3D_noncontrast_coronair_MRA
# technieken#3D_contrast_MRA
# technieken#4D_dynamische_contrast_MRA
# technieken#rust_perfusie
# technieken#stress_perfusie
# technieken#early_gadolinium_enhancement
# technieken#late_gadolinium_enhancement
# technieken#native_T1_mapping
# technieken#post_contrast_T1_mapping
# lengte
# gewicht
# BSA
# BMI
# sedatie
# ritme
# HF
# contrast
# mlcontrast
# stressor
# kwaliteit
# artefacten#geen_van_betekenis
# artefacten#ademhaling
# artefacten#irregulair_hartritme
# artefacten#flow
# artefacten#prothese_materiaal
# artefacten#klepprothese
# artefacten#cardiaal_device
# artefacten#patint_niet_coperatief
# artefacten#ECG_triggerprobleem
# artefacten#RF_interferentie_door_factoren_buiten_de_scanner
# LVEDD
# IVSd
# PWd
# LVEDV
# LVEDVi
# LVESV
# LVESVi
# LVSV
# LVEF
# LVM
# LVMi
# LVdim
# LVH#normaal
# LVH#geringe_hypertrofie
# LVH#matige_hypertrofie
# LVH#ernstige_hypertrofie
# LVH#concentrisch
# LVH#excentrisch
# LVH#asymmetrisch
# LVH#apicaal
# LVH#regionale_wandverdunning
# LVH#lokale_wandverdunning
# LVF#normaal
# LVF#goed
# LVF#redelijk
# LVF#matig
# LVF#matig_tot_slecht
# LVF#slecht
# LVF#globaal
# LVF#regionaal
# LVF#globaal_en_regionaal
# LVF#geen_regionale_wandbewegingsstoornissen
# LVF#dyssynchroon_contractiepatroon
# LVF#niet_te_beoordelen
# IVS#normaal
# IVS#proximaal_kamerseptum_verdikking
# IVS#abnormaal_kamerseptum_beweging
# IVS#abnormaal_kamerseptum_beweging_restrictie
# IVS#paradoxaal_kamerseptum_beweging_bij_LBTB
# IVS#paradoxaal_kamerseptum_beweging_RV_belasting
# IVS#congenitaal_defect
# IVS#gecorrigeerd_congenitaal_defect
# aanvLV
# RVEDD
# TAPSE
# RVEDV
# RVEDVi
# RVESV
# RVESVi
# RVSV
# RVEF
# RVdim
# RVH
# RVF#normaal
# RVF#goed
# RVF#redelijk
# RVF#matig
# RVF#matigslecht
# RVF#slecht
# RVF#geen_regionale_wandbewegingsstoornissen
# RVF#regionale_akinesie
# RVF#regionale_dyskinesie
# RVF#niet_te_beoordelen
# aanvRV
# Cventr
# LA
# LA4CV
# LA2CV
# LAL
# LA2D
# LA2Di
# LA3D
# LA3Di
# RA
# RA3D
# RA3Di
# IAS#normaal
# IAS#floppy
# IAS#aneurysmatisch
# IAS#buigt_naar_LA
# IAS#buigt_naar_RA
# IAS#lipomateuze_hypertrofie
# IAS#congenitaal_defect
# IAS#gecorrigeerd_congenitaal_defect
# IAS#niet_te_beoordelen
# aanvLARA
# Catria
# Kleplijden
# AoFW
# AoReg
# AoRegFrac
# AoPG
# AoVplani
# AoV#normale_morfologie
# AoV#tricuspide
# AoV#sclerotisch
# AoV#gecalcificeerd
# AoV#verminderde_opening
# AoV#bicuspide
# AoV#mechanische_kunstklep
# AoV#biologische_kunstklep
# AoV#status_na_TAVI
# AoV#niet_gevisualiseerd
# AoS
# AoI
# MVreg
# MVplani
# MV#normale_morfologie
# MV#verdikt_gecalcificeerd
# MV#verdikt_AMVL
# MV#verdikt_PMVL
# MV#rheumatisch
# MV#diastolische_doming
# MV#systolische_billowing
# MV#SAM_MV
# MV#chordale_SAM
# MV#parachute_MV
# MV#annulus_dilatatie
# MV#annulus_calcificatie
# MV#tenting
# MV#prolaps_AMVL
# MV#prolaps_PMVL
# MV#flail_leaflet
# MV#cleft_MV
# MV#congenitale_afwijking
# MV#status_na_annuloplastiek
# MV#biologische_kunstklep
# MV#mechanische_kunstklep
# MV#niet_gevisualiseerd
# MI
# MS
# PFW
# PReg
# PRegFrac
# PVPG
# PV#normale_morfologie
# PV#verdikt
# PV#sclerotisch
# PV#gecalcificeerd
# PV#verminderde_opening
# PV#status_na_homograft
# PV#status_na_operatie
# PV#niet_gevisualiseerd
# PS
# PI
# TV#normale_morfologie
# TV#verdikt
# TV#annulusdilatatie
# TV#gecalcificeerd
# TV#verminderde_opening
# TV#status_na_annuloplastiek
# TV#biologische_kunstklep
# TV#mechanische_kunstklep
# TV#pacemakerdraad
# TV#prolaps
# TV#niet_gevisualiseerd
# TI
# TS
# aanvKlep
# Cklep
# annulus
# sinus
# sinusindex
# STjunctie
# ascendens
# ascendensindex
# boog
# isthmus
# descAP
# descDIAF
# abdREN
# abdBIF
# aorta#normale_dimensies_aorta_thoracalis
# aorta#normale_dimensies_aorta_abdominalis
# aorta#gelongeerd_beloop
# aorta#dilatatie_aorta_thoracalis
# aorta#dilatatie_aorta_abdominalis
# aorta#aneurysma_aorta_thoracalis
# aorta#aneurysma_aorta_abdominalis
# aorta#wandstandig_thrombus
# aorta#minimale_atherosclerose
# aorta#uitgebreide_atherosclerose
# aorta#dissectie_Stanford_A_DeBakey_I
# aorta#dissectie_Stanford_A_DeBakey_II
# aorta#dissectie_Stanford_B_DeBakey_III
# aorta#onvoldoende_gevisualiseerd
# truncpulmonalis
# RPA
# LPA
# PulmArt#normale_dimensies
# PulmArt#normale_dimensie_truncus_pulmonalis
# PulmArt#normale_dimensie_rechter_a_pulmonalis
# PulmArt#normale_dimensie_linker_a_pulmonalis
# PulmArt#dilatatie_truncus_pulmonalis
# PulmArt#dilatatie_rechter_a_pulmonalis
# PulmArt#dilatatie_linker_a_pulmonalis
# PulmArt#onvoldoende_gevisualiseerd
# Pulm#normale_inmonding_in_LA
# Pulm#common_ostium_links
# Pulm#common_ostium_rechts
# Pulm#gescheiden_ostia
# Pulm#accessoire_rechter_PV
# Pulm#abnormale_pulmonale_veneuze_return
# Bvaten
# Cvaten
# concentratie
# stress
# rust
# aankleuring
# distributie#ischemisch
# distributie#ischemisch_subendocardiaal
# distributie#ischemisch_transmuraal
# distributie#nonischemisch
# distributie#nonischemisch_epicardiaal
# distributie#nonischemisch_mid_myocardiaal
# distributie#nonischemisch_insertie_RV
# distributie#nonischemisch_bij_hypertrofie
# distributie#nonischemisch_globaal_endocardiaal
# distributie#gemengd
# addcontrast#geen
# addcontrast#thrombus
# addcontrast#linker_ventrikelthrombus
# addcontrast#protruding_thrombus
# addcontrast#muraal_thrombus
# addcontrast#geen_thrombus
# addcontrast#microvasculaire_schade
# addcontrast#geen_microvasculaire_schade
# addcontrast#rechterventrikeluitbreiding
# addcontrast#gedeeltelijke_aankleuring_tumor
# addcontrast#volledige_aankleuring_tumor
# aanvcontrast
# Clge
# segm_invullen
# segm_tekst
# segm_tabel_basaal_anterior_wandbeweging
# segm_tabel_basaal_anterior_stress_perfusie
# segm_tabel_basaal_anterior_LGE
# segm_tabel_basaal_anterior_interpretatie
# segm_tabel_basaal_anteroseptaal_wandbeweging
# segm_tabel_basaal_anteroseptaal_stress_perfusie
# segm_tabel_basaal_anteroseptaal_LGE
# segm_tabel_basaal_anteroseptaal_interpretatie
# segm_tabel_basaal_inferoseptaal_wandbeweging
# segm_tabel_basaal_inferoseptaal_stress_perfusie
# segm_tabel_basaal_inferoseptaal_LGE
# segm_tabel_basaal_inferoseptaal_interpretatie
# segm_tabel_basaal_inferior_wandbeweging
# segm_tabel_basaal_inferior_stress_perfusie
# segm_tabel_basaal_inferior_LGE
# segm_tabel_basaal_inferior_interpretatie
# segm_tabel_basaal_inferolateraal_wandbeweging
# segm_tabel_basaal_inferolateraal_stress_perfusie
# segm_tabel_basaal_inferolateraal_LGE
# segm_tabel_basaal_inferolateraal_interpretatie
# segm_tabel_basaal_anterolateraal_wandbeweging
# segm_tabel_basaal_anterolateraal_stress_perfusie
# segm_tabel_basaal_anterolateraal_LGE
# segm_tabel_basaal_anterolateraal_interpretatie
# segm_tabel_mid_anterior_wandbeweging
# segm_tabel_mid_anterior_stress_perfusie
# segm_tabel_mid_anterior_LGE
# segm_tabel_mid_anterior_interpretatie
# segm_tabel_mid_anteroseptaal_wandbeweging
# segm_tabel_mid_anteroseptaal_stress_perfusie
# segm_tabel_mid_anteroseptaal_LGE
# segm_tabel_mid_anteroseptaal_interpretatie
# segm_tabel_mid_inferoseptaal_wandbeweging
# segm_tabel_mid_inferoseptaal_stress_perfusie
# segm_tabel_mid_inferoseptaal_LGE
# segm_tabel_mid_inferoseptaal_interpretatie
# segm_tabel_mid_inferior_wandbeweging
# segm_tabel_mid_inferior_stress_perfusie
# segm_tabel_mid_inferior_LGE
# segm_tabel_mid_inferior_interpretatie
# segm_tabel_mid_inferolateraal_wandbeweging
# segm_tabel_mid_inferolateraal_stress_perfusie
# segm_tabel_mid_inferolateraal_LGE
# segm_tabel_mid_inferolateraal_interpretatie
# segm_tabel_mid_anterolateraal_wandbeweging
# segm_tabel_mid_anterolateraal_stress_perfusie
# segm_tabel_mid_anterolateraal_LGE
# segm_tabel_mid_anterolateraal_interpretatie
# segm_tabel_apicaal_anterior_wandbeweging
# segm_tabel_apicaal_anterior_stress_perfusie
# segm_tabel_apicaal_anterior_LGE
# segm_tabel_apicaal_anterior_interpretatie
# segm_tabel_apicaal_septaal_wandbeweging
# segm_tabel_apicaal_septaal_stress_perfusie
# segm_tabel_apicaal_septaal_LGE
# segm_tabel_apicaal_septaal_interpretatie
# segm_tabel_apicaal_inferior_wandbeweging
# segm_tabel_apicaal_inferior_stress_perfusie
# segm_tabel_apicaal_inferior_LGE
# segm_tabel_apicaal_inferior_interpretatie
# segm_tabel_apicaal_lateraal_wandbeweging
# segm_tabel_apicaal_lateraal_stress_perfusie
# segm_tabel_apicaal_lateraal_LGE
# segm_tabel_apicaal_lateraal_interpretatie
# segm_tabel_apex_wandbeweging
# segm_tabel_apex_stress_perfusie
# segm_tabel_apex_LGE
# segm_tabel_apex_interpretatie
# IS
# weefsel
# T1TSE
# T1map
# T2TSE
# T2map
# T2sterhart
# T2sterlever
# KwantIJzer
# Cweefsel
# pericardafw
# pericard#normaal
# pericard#gering_verdikt
# pericard#matig_verdikt
# pericard#ernstig_verdikt
# pericard#lokaal
# pericard#rondom
# pericard#cyste
# pericard#massa
# pericard#niet_te_beoordelen
# maxpericarddikte
# PE#geen
# PE#gering
# PE#matig
# PE#ernstig
# PE#lokaal
# PE#rondom
# PE#intrapericardiaal_fibrine
# PE#intrapericardiaal_thrombus
# PE#niet_gevisualiseerd
# collaps#geen_collaps_cardiale_compartimenten
# collaps#rechter_atrium
# collaps#rechter_ventrikel
# collaps#linker_atrium
# collaps#linker_ventrikel
# collaps#niet_te_beoordelen
# aanvPericard
# Cpericard
# congenitaal
# CongGroep#ASD_shunt
# CongGroep#VSD_shunt
# CongGroep#overige_shunts_DORV_PDA_aberrante_longvene
# CongGroep#aorta__aortaklep
# CongGroep#Ebstein_anomalie
# CongGroep#tetralogie_van_Fallot
# CongGroep#transpositie_grote_vaten_dTGA_CCTGA
# CongGroep#monoventrikel_fysiologie_Glenn_Fontan_AVSD_hypopl0
# CongGroep#coronair_anomalie
# CongGroep#Marfan_syndroom
# CongGroep#overig
# situs#situs_solitus
# situs#situs_inversus
# situs#situs_ambiguous
# situs#dextrocardie
# situs#mesocardie
# situs#levocardie
# situs#AV_concordantie
# situs#AV_discordantie
# situs#VA_concordantie
# situs#VA_discordantie
# AortaCong#geen
# AortaCong#coarctatio
# AortaCong#patente_ductus_arteriosus
# AortaCong#normale_aftakking_boogvaten
# AortaCong#carotis_communis_links_uit_tr_brachiocephalicus
# AortaCong#arteria_lusoria
# AoVmorfologie
# coronair
# anomalie
# ASD#geen
# ASD#ostium_secundum_defect
# ASD#ostium_primum_defect
# ASD#inferior_sinus_venosus_defect
# ASD#superior_sinus_venosus_defect
# ASD#ASD_met_closure_device
# ASD#chirurgisch_gesloten_ASD
# ASD#restshunt_na_sluiting
# ASD#geen_restshunt_na_sluiting
# ASD#niet_te_beoordelen
# venoatriaal#persisterende_linker_vena_cava_superior
# venoatriaal#partile_abnormale_pulmonale_veneuze_return
# venoatriaal#totale_abnormale_pulmonale_veneuze_return
# venoatriaal#abnormale_veneuze_return
# VSD#geen
# VSD#perimembraneus
# VSD#muscular
# VSD#chirurgische_gesloten
# VSD#restshunt_na_sluiting
# VSD#geen_restshunt_na_sluiting
# VSD#niet_te_beoordelen
# shunt
# aanvcongen
# Ccongenitaal
# Extracard
# PlV#geen
# PlV#gering
# PlV#matig
# PlV#ernstig
# PlV#rechts
# PlV#links
# PlV#beiderzijds
# extracardiaal#geen
# extracardiaal#niercysten
# extracardiaal#levercysten
# extracardiaal#hemangioom
# extracardiaal#cholelithiasis
# extracardiaal#hernia_diafragmatica
# extracardiaal#intrathoracale_maag
# extracardiaal#pulmonale_nodus
# extracardiaal#pulmonaal_infiltraat
# extracardiaal#atelectase
# extracardiaal#mediastinale_klieren
# extracardiaal#durale_ectasien
# extracardiaal#cerclagedraden_sternum
# extracardiaal#borstprothesen
# extracardiaal#ruimte_innemend_proces
# extracardiaal#hamartoom
# aanvextracard
# Cextracardiaal
# advies
# voorbeeld
# demo
# CMRcompl
# majcom
# majcompl#dood
# majcompl#ventrikelfibrilleren
# majcompl#sustained_VT
# majcompl#cardiac_arrest
# majcompl#anafylactische_shock
# mincom
# mincompl#contrastallergie_zonder_shock
# mincompl#angina_pectoris
# mincompl#dyspnoe
# mincompl#nonsustained_VT
# mincompl#paroxysmaal_atriumfibrilleren
# mincompl#significante_toename_in_bloeddruk_240120mmHg
# mincompl#significante_toename_in_systolische_bloeddruk_40mm0
# mincompl#bronchospasme_bij_adenosine
# mincompl#2e_of_3e_grds_AV_blok
# mincompl#misselijkheid
# mincompl#lokale_complicaties_bv_door_infuus
# mincompl#claustrofobie
# diagnose
# neven
# nevendiagnose#geen
# nevendiagnose#coronairlijden
# nevendiagnose#ischemie
# nevendiagnose#gedilateerde_CMP
# nevendiagnose#hypertrofische_CMP
# nevendiagnose#myocarditis
# nevendiagnose#ARVC
# nevendiagnose#sarcoidose
# nevendiagnose#amyloidose
# nevendiagnose#takotsubo_CMP
# nevendiagnose#thalassemie__ijzerstapeling
# nevendiagnose#restrictieve_CMP
# nevendiagnose#ziekte_van_AndersonFabry
# nevendiagnose#overige_CMP
# nevendiagnose#afstoting_na_harttransplantatie
# nevendiagnose#pericardziekte
# nevendiagnose#cardiale_trombus
# nevendiagnose#cardiale_tumor
# nevendiagnose#kleplijden
# nevendiagnose#congenitale_hartziekte
# nevendiagnose#aortapathologie
# nevendiagnose#pulmonale_vaatpathologie
# nevendiagnose#relevante_extracardiale_bevinding
# excldiagnose#geen
# excldiagnose#coronairlijden
# excldiagnose#ischemie
# excldiagnose#gedilateerde_CMP
# excldiagnose#hypertrofische_CMP
# excldiagnose#myocarditis
# excldiagnose#ARVC
# excldiagnose#sarcoidose
# excldiagnose#amyloidose
# excldiagnose#takotsubo_CMP
# excldiagnose#thalassemie__ijzerstapeling
# excldiagnose#restrictieve_CMP
# excldiagnose#ziekte_van_AndersonFabry
# excldiagnose#overige_CMP
# excldiagnose#afstoting_na_harttransplantatie
# excldiagnose#pericardziekte
# excldiagnose#cardiale_trombus
# excldiagnose#cardiale_tumor
# excldiagnose#kleplijden
# excldiagnose#congenitale_hartziekte
# excldiagnose#aortapathologie
# excldiagnose#pulmonale_vaatpathologie
# excldiagnose#relevante_extracardiale_bevinding
# impact
# vermeden#geen
# vermeden#PET__SPECT
# vermeden#CT_coronair_angiografie
# vermeden#invasieve_coronairangiografie
# vermeden#dobutamine_echocardiografie
# medwijzig
# invproc
# CMRopname
# CMRontslag
# folllow_up_MK_calc
# day_to_ICDtherapy_1y_MK
# day_to_ICDtherapy_2y_MK
# day_to_ICDtherapy_3y_MK
# day_to_ICDtherapy_4y_MK
# day_to_ICDtherapy_5y_MK
# day_to_ICDtherapy_10y_MK
# sum_slices
# max_slices

# %%
df['cardiomyopathie'].unique()
# Out:
# array(['1', '2', '3', '0', '4', ' '], dtype=object)

# %%
(df[df['Data split'].isin(['train', 'validation', 'test'])]['cardiomyopathie'].isin(['0', '1', '2', '3', '4'])).sum()
# Out:
# 125

# %%
len(list(df['SubjectID'][(df['Gesegmenteerd?'] == 'Ja') & df['Data split'].isin(['train'])]))
# Out:
# 86

# %%
len(list(df['SubjectID'][(df['Gesegmenteerd?'] == 'Ja') & df['Data split'].isin(['validation'])]))
# Out:
# 12

# %%
len(list(df['SubjectID'][(df['Gesegmenteerd?'] == 'Ja') & df['Data split'].isin(['test'])]))
# Out:
# 24
